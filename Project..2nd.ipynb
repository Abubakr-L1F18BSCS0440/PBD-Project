# %%
import pandas as pd
import numpy as np
df=pd.read_csv('TA_restaurants_curated.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']      1.0     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0     4.5
# 2  ['Mediterranean', 'French', 'International', '...      3.0     4.5
# 3  ['French', 'European', 'International', 'Conte...      4.0     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...      5.0     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
#                                              Reviews  \
# 0  [['Just like home', 'A Warm Welcome to Wintry ...
# 1  [['Great food and staff', 'just perfect'], ['0...
# 2  [['Satisfaction', 'Delicious old school restau...
# 3  [['True five star dinner', 'A superb evening o...
# 4  [['Best meal.... EVER', 'super food experience...
#
#                                               URL_TA      ID_TA
# 0  /Restaurant_Review-g188590-d11752080-Reviews-M...  d11752080
# 1  /Restaurant_Review-g188590-d693419-Reviews-De_...    d693419
# 2  /Restaurant_Review-g188590-d696959-Reviews-La_...    d696959
# 3  /Restaurant_Review-g188590-d1239229-Reviews-Vi...   d1239229
# 4  /Restaurant_Review-g188590-d6864170-Reviews-Li...   d6864170

# %%
missing_values=df.isnull()

# %%
missing_values
# Out:
#         Unnamed: 0   Name   City  Cuisine Style  Ranking  Rating  Price Range  \
# 0            False  False  False          False    False   False        False
# 1            False  False  False          False    False   False        False
# 2            False  False  False          False    False   False        False
# 3            False  False  False          False    False   False        False
# 4            False  False  False          False    False   False        False
# ...            ...    ...    ...            ...      ...     ...          ...
# 125522       False  False  False           True     True    True         True
# 125523       False  False  False          False     True    True         True
# 125524       False  False  False           True     True    True         True
# 125525       False  False  False          False     True    True         True
# 125526       False  False  False          False     True    True        False
#
#         Number of Reviews  Reviews  URL_TA  ID_TA
# 0                   False    False   False  False
# 1                   False    False   False  False
# 2                   False    False   False  False
# 3                   False    False   False  False
# 4                   False    False   False  False
# ...                   ...      ...     ...    ...
# 125522               True     True   False  False
# 125523               True     True   False  False
# 125524               True     True   False  False
# 125525               True     True   False  False
# 125526               True     True   False  False
#
# [125527 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'City', 'Cuisine Style', 'Ranking', 'Rating',
#        'Price Range', 'Number of Reviews', 'Reviews', 'URL_TA', 'ID_TA'],
#       dtype='object')

# %%
missing_values.sum()
# Out:
# Unnamed: 0               0
# Name                     0
# City                     0
# Cuisine Style        31351
# Ranking               9651
# Rating                9630
# Price Range          47855
# Number of Reviews    17344
# Reviews               9616
# URL_TA                   0
# ID_TA                    0
# dtype: int64

# %%
df.replace('?',np.nan,inplace=True)

# %%
import numpy as np
import pandas as pd

# %%
avg=df['Ranking'].mean()

# %%
avg
# Out:
# 3657.46397873589

# %%
df['Ranking'].isnull().sum()
# Out:
# 9651

# %%
df['Ranking'].replace(np.nan,avg,inplace=True)

# %%
df['Ranking'].isnull().sum()
# Out:
# 0

# %%
df['Rating'].isnull().sum()
# Out:
# 9630

# %%
maxi=df['Rating'].value_counts().idxmax()

# %%
df['Rating'].replace(np.nan,maxi,inplace=True)

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
df['Number of Reviews'].isnull().sum()
# Out:
# 17344

# %%
avg=df['Number of Reviews'].mean()

# %%
df['Number of Reviews'].replace(np.nan,avg,inplace=True)

# %%
df['Number of Reviews'].isnull().sum()
# Out:
# 0

# %%
df['Price Range'].isnull().sum()
# Out:
# 47855

# %%
frq=df['Price Range'].value_counts().idxmax()

# %%
df['Price Range'].replace(np.nan,frq,inplace=True)

# %%
df['Price Range'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Name                     0
# City                     0
# Cuisine Style        31351
# Ranking                  0
# Rating                   0
# Price Range              0
# Number of Reviews        0
# Reviews               9616
# URL_TA                   0
# ID_TA                    0
# dtype: int64

# %%
frq=df['Reviews'].value_counts().idxmax()
df['Reviews'].replace(np.nan,frq,inplace=True)

# %%
frq=df['Cuisine Style'].value_counts().idxmax()

# %%
df['Cuisine Style'].replace(np.nan,frq,inplace=True)

# %%
df['Cuisine Style'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# City                 0
# Cuisine Style        0
# Ranking              0
# Rating               0
# Price Range          0
# Number of Reviews    0
# Reviews              0
# URL_TA               0
# ID_TA                0
# dtype: int64

# %%
df[['Cuisine Style','Price Range']]
# Out:
#                                             Cuisine Style Price Range
# 0                         ['French', 'Dutch', 'European']    $$ - $$$
# 1       ['Dutch', 'European', 'Vegetarian Friendly', '...        $$$$
# 2       ['Mediterranean', 'French', 'International', '...        $$$$
# 3       ['French', 'European', 'International', 'Conte...        $$$$
# 4       ['Dutch', 'European', 'International', 'Vegeta...        $$$$
# ...                                                   ...         ...
# 125522                                        ['Italian']    $$ - $$$
# 125523                                           ['Cafe']    $$ - $$$
# 125524                                        ['Italian']    $$ - $$$
# 125525                                      ['Fast Food']    $$ - $$$
# 125526     ['Italian', 'Pizza', 'Mediterranean', 'Diner']    $$ - $$$
#
# [125527 rows x 2 columns]

# %%
df['Ranking']=df['Ranking'].astype(int ,copy=True)

# %%
df['Ranking']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#           ...
# 125522    3657
# 125523    3657
# 125524    3657
# 125525    3657
# 125526    3657
# Name: Ranking, Length: 125527, dtype: int32

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.xlabel('Ranking')
plt.pyplot.ylabel('count')
plt.pyplot.title('Ranking Bins')
plt.pyplot.hist(df['Ranking'])
# Out:
# (array([46159., 25647., 22626., 10378.,  6145.,  3874.,  3289.,  3288.,
#          2477.,  1644.]),
#  array([1.00000e+00, 1.64530e+03, 3.28960e+03, 4.93390e+03, 6.57820e+03,
#         8.22250e+03, 9.86680e+03, 1.15111e+04, 1.31554e+04, 1.47997e+04,
#         1.64440e+04]),
#  <a list of 10 Patch objects>)

# %%
df.head()
# Out:
#    Unnamed: 0                        Name       City  \
# 0           0  Martine of Martine's Table  Amsterdam
# 1           1         De Silveren Spiegel  Amsterdam
# 2           2                     La Rive  Amsterdam
# 3           3                    Vinkeles  Amsterdam
# 4           4   Librije's Zusje Amsterdam  Amsterdam
#
#                                        Cuisine Style  Ranking  Rating  \
# 0                    ['French', 'Dutch', 'European']        1     5.0
# 1  ['Dutch', 'European', 'Vegetarian Friendly', '...        2     4.5
# 2  ['Mediterranean', 'French', 'International', '...        3     4.5
# 3  ['French', 'European', 'International', 'Conte...        4     5.0
# 4  ['Dutch', 'European', 'International', 'Vegeta...        5     4.5
#
#   Price Range  Number of Reviews  \
# 0    $$ - $$$              136.0
# 1        $$$$              812.0
# 2        $$$$              567.0
# 3        $$$$              564.0
# 4        $$$$              316.0
#
#                                              Reviews  \
# 0  [['Just like home', 'A Warm Welcome to Wintry ...
# 1  [['Great food and staff', 'just perfect'], ['0...
# 2  [['Satisfaction', 'Delicious old school restau...
# 3  [['True five star dinner', 'A superb evening o...
# 4  [['Best meal.... EVER', 'super food experience...
#
#                                               URL_TA      ID_TA
# 0  /Restaurant_Review-g188590-d11752080-Reviews-M...  d11752080
# 1  /Restaurant_Review-g188590-d693419-Reviews-De_...    d693419
# 2  /Restaurant_Review-g188590-d696959-Reviews-La_...    d696959
# 3  /Restaurant_Review-g188590-d1239229-Reviews-Vi...   d1239229
# 4  /Restaurant_Review-g188590-d6864170-Reviews-Li...   d6864170

# %%
bins=np.linspace(min(df['Rating']),max(df['Rating']),6)
label=['V Low','Low','Medium','High','V Heigh']
df['Level']=pd.cut(df['Rating'],bins,labels=label,include_lowest=True)

# %%
df[['Name','Rating','City','Level']].head()
# Out:
#                          Name  Rating       City    Level
# 0  Martine of Martine's Table     5.0  Amsterdam  V Heigh
# 1         De Silveren Spiegel     4.5  Amsterdam  V Heigh
# 2                     La Rive     4.5  Amsterdam  V Heigh
# 3                    Vinkeles     5.0  Amsterdam  V Heigh
# 4   Librije's Zusje Amsterdam     4.5  Amsterdam  V Heigh

# %%
df[df['Name']=="Martine of Martine's Table"].groupby("Name").mean()
# Out:
#                             Unnamed: 0  Ranking  Rating  Number of Reviews
# Name
# Martine of Martine's Table           0        1     5.0              136.0

# %%
df.groupby('City').describe()
# Out:
#            Unnamed: 0                                                       \
#                 count    mean          std  min      25%     50%       75%
# City
# Amsterdam      3434.0  1716.5   991.454739  0.0   858.25  1716.5   2574.75
# Athens         1938.0   968.5   559.596730  0.0   484.25   968.5   1452.75
# Barcelona      8425.0  4212.0  2432.232342  0.0  2106.00  4212.0   6318.00
# Berlin         7078.0  3538.5  2043.386935  0.0  1769.25  3538.5   5307.75
# Bratislava     1067.0   533.0   308.160672  0.0   266.50   533.0    799.50
# Brussels       3204.0  1601.5   925.059458  0.0   800.75  1601.5   2402.25
# Budapest       2606.0  1302.5   752.431724  0.0   651.25  1302.5   1953.75
# Copenhagen     2109.0  1054.0   608.960179  0.0   527.00  1054.0   1581.00
# Dublin         2082.0  1040.5   601.165950  0.0   520.25  1040.5   1560.75
# Edinburgh      1865.0   932.0   538.523444  0.0   466.00   932.0   1398.00
# Geneva         1572.0   785.5   453.941626  0.0   392.75   785.5   1178.25
# Hamburg        3131.0  1565.0   903.986172  0.0   782.50  1565.0   2347.50
# Helsinki       1228.0   613.5   354.637373  0.0   306.75   613.5    920.25
# Krakow         1354.0   676.5   391.010443  0.0   338.25   676.5   1014.75
# Lisbon         3986.0  1992.5  1150.803415  0.0   996.25  1992.5   2988.75
# Ljubljana       501.0   250.0   144.770508  0.0   125.00   250.0    375.00
# London        18212.0  9105.5  5257.495887  0.0  4552.75  9105.5  13658.25
# Luxembourg      657.0   328.0   189.803846  0.0   164.00   328.0    492.00
# Lyon           2930.0  1464.5   845.962470  0.0   732.25  1464.5   2196.75
# Madrid         9543.0  4771.0  2754.971143  0.0  2385.50  4771.0   7156.50
# Milan          6687.0  3343.0  1930.514957  0.0  1671.50  3343.0   5014.50
# Munich         2995.0  1497.0   864.726354  0.0   748.50  1497.0   2245.50
# Oporto         1580.0   789.5   456.251027  0.0   394.75   789.5   1184.25
# Oslo           1213.0   606.0   350.307246  0.0   303.00   606.0    909.00
# Paris         14874.0  7436.5  4293.898287  0.0  3718.25  7436.5  11154.75
# Prague         4859.0  2429.0  1402.816809  0.0  1214.50  2429.0   3643.50
# Rome           5949.0  2974.0  1717.472707  0.0  1487.00  2974.0   4461.00
# Stockholm      2705.0  1352.0   781.010563  0.0   676.00  1352.0   2028.00
# Vienna         3724.0  1861.5  1075.170529  0.0   930.75  1861.5   2792.25
# Warsaw         2352.0  1175.5   679.108239  0.0   587.75  1175.5   1763.25
# Zurich         1667.0   833.0   481.365765  0.0   416.50   833.0   1249.50
#
#                      Ranking               ... Rating      Number of Reviews  \
#                 max    count         mean  ...    75%  max             count
# City                                       ...
# Amsterdam    3433.0   3434.0  1738.288002  ...    4.5  5.0            3434.0
# Athens       1937.0   1938.0  1109.853457  ...    4.5  5.0            1938.0
# Barcelona    8424.0   8425.0  3879.996083  ...    4.5  5.0            8425.0
# Berlin       7077.0   7078.0  3233.810257  ...    4.5  5.0            7078.0
# Bratislava   1066.0   1067.0   978.241799  ...    4.5  5.0            1067.0
# Brussels     3203.0   3204.0  1635.167915  ...    4.5  5.0            3204.0
# Budapest     2605.0   2606.0  1375.702993  ...    4.5  5.0            2606.0
# Copenhagen   2108.0   2109.0  1166.623044  ...    4.5  5.0            2109.0
# Dublin       2081.0   2082.0  1143.574928  ...    4.5  5.0            2082.0
# Edinburgh    1864.0   1865.0  1036.559786  ...    4.5  5.0            1865.0
# Geneva       1571.0   1572.0  1016.376590  ...    4.5  5.0            1572.0
# Hamburg      3130.0   3131.0  1660.124880  ...    4.5  5.0            3131.0
# Helsinki     1227.0   1228.0   781.446254  ...    4.5  5.0            1228.0
# Krakow       1353.0   1354.0   867.243722  ...    4.5  5.0            1354.0
# Lisbon       3985.0   3986.0  1981.440291  ...    4.5  5.0            3986.0
# Ljubljana     500.0    501.0   453.570858  ...    4.5  5.0             501.0
# London      18211.0  18212.0  7778.026466  ...    4.5  5.0           18212.0
# Luxembourg    656.0    657.0   489.722983  ...    4.5  5.0             657.0
# Lyon         2929.0   2930.0  1540.825939  ...    4.5  5.0            2930.0
# Madrid       9542.0   9543.0  4346.128366  ...    4.0  5.0            9543.0
# Milan        6686.0   6687.0  3170.804098  ...    4.0  5.0            6687.0
# Munich       2994.0   2995.0  1573.244407  ...    4.5  5.0            2995.0
# Oporto       1579.0   1580.0   903.129114  ...    4.5  5.0            1580.0
# Oslo         1212.0   1213.0   762.577082  ...    4.5  5.0            1213.0
# Paris       14873.0  14874.0  6796.071803  ...    4.5  5.0           14874.0
# Prague       4858.0   4859.0  2311.630171  ...    4.5  5.0            4859.0
# Rome         5948.0   5949.0  2975.116490  ...    4.5  5.0            5949.0
# Stockholm    2704.0   2705.0  1450.619224  ...    4.5  5.0            2705.0
# Vienna       3723.0   3724.0  1867.937164  ...    4.5  5.0            3724.0
# Warsaw       2351.0   2352.0  1294.443878  ...    4.5  5.0            2352.0
# Zurich       1666.0   1667.0   922.791242  ...    4.5  5.0            1667.0
#
#                                                                         \
#                   mean         std  min    25%         50%         75%
# City
# Amsterdam   134.285963  275.971243  2.0  14.00   59.500000  125.184983
# Athens      105.193277  257.416184  2.0   8.00   31.000000  125.184983
# Barcelona   138.384304  330.648331  2.0  12.00   51.000000  125.184983
# Berlin       80.096554  180.308825  2.0   8.00   27.000000  125.184983
# Bratislava   74.029517  143.609068  2.0   7.00   27.000000  125.184983
# Brussels     96.941855  219.279430  2.0  11.00   42.000000  125.184983
# Budapest    146.874036  366.599535  2.0   9.00   41.000000  125.184983
# Copenhagen  104.758926  192.208119  2.0  10.00   42.000000  125.184983
# Dublin      163.439763  335.034539  2.0  13.00   61.000000  137.000000
# Edinburgh   226.313457  396.820564  2.0  18.00   92.000000  249.000000
# Geneva       78.129972  121.084481  2.0  13.75   45.000000  125.184983
# Hamburg      63.278733   87.401791  2.0   8.00   27.000000  125.184983
# Helsinki     69.463691  113.692344  2.0   9.00   26.000000  115.000000
# Krakow      137.392579  304.303226  2.0  10.00   45.000000  125.184983
# Lisbon      130.550976  297.785410  2.0  10.00   46.000000  125.184983
# Ljubljana    99.986814  215.126981  2.0   8.00   26.000000  125.184983
# London      136.970132  315.774135  2.0  12.00   60.000000  125.184983
# Luxembourg   83.894336  105.021110  2.0  14.00   45.000000  125.184983
# Lyon         93.378131  173.556123  2.0  12.00   42.500000  125.184983
# Madrid      102.104633  251.961091  2.0  10.00   38.000000  125.184983
# Milan       163.996111  327.972549  2.0  14.00   70.000000  171.000000
# Munich       90.936976  357.066975  2.0  12.00   41.000000  125.184983
# Oporto      138.368261  273.890364  2.0  13.00   51.500000  125.184983
# Oslo         96.172063  160.980764  2.0  11.00   38.000000  125.184983
# Paris       116.780816  236.307597  2.0  14.00   55.000000  125.184983
# Prague      120.639506  300.392474  2.0   8.00   43.000000  125.184983
# Rome        288.705808  510.239468  2.0  36.00  125.184983  339.000000
# Stockholm    79.437415  139.803810  2.0   9.00   31.000000  125.184983
# Vienna       90.375173  238.705208  2.0   8.00   31.000000  125.184983
# Warsaw       71.771696  141.929008  2.0   7.00   24.000000  125.184983
# Zurich       81.032395  163.805660  2.0  11.00   36.000000  125.184983
#
#
#                 max
# City
# Amsterdam    6777.0
# Athens       4234.0
# Barcelona   10504.0
# Berlin       4452.0
# Bratislava   2578.0
# Brussels     6437.0
# Budapest     7575.0
# Copenhagen   3426.0
# Dublin       4453.0
# Edinburgh    5251.0
# Geneva       1836.0
# Hamburg      1327.0
# Helsinki     1488.0
# Krakow       4608.0
# Lisbon       7560.0
# Ljubljana    2533.0
# London      12910.0
# Luxembourg    729.0
# Lyon         5402.0
# Madrid      11497.0
# Milan       13862.0
# Munich      16478.0
# Oporto       3206.0
# Oslo         1696.0
# Paris       10706.0
# Prague       7699.0
# Rome        10300.0
# Stockholm    1784.0
# Vienna       7140.0
# Warsaw       2356.0
# Zurich       3951.0
#
# [31 rows x 32 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.boxplot(x='Rating',y='Ranking',data=df)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'City', 'Cuisine Style', 'Ranking', 'Rating',
#        'Price Range', 'Number of Reviews', 'Reviews', 'URL_TA', 'ID_TA',
#        'Level'],
#       dtype='object')

# %%
sns.distplot(df['Rating'])

# %%
sns.distplot(df['Ranking'])

# %%
plt.scatter(df['Ranking'],df['Number of Reviews'])

# %%
df[df['City']=="Amsterdam"].groupby("City").mean()
# Out:
#            Unnamed: 0      Ranking    Rating  Number of Reviews
# City
# Amsterdam      1716.5  1738.288002  4.111969         134.285963
